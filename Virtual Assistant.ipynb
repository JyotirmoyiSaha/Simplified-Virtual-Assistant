# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in g:\anaconda2\lib\site-packages (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
# Requirement already satisfied: pywin32; platform_system == "Windows" in g:\anaconda2\lib\site-packages (from pyttsx3) (227)
# Requirement already satisfied: comtypes; platform_system == "Windows" in g:\anaconda2\lib\site-packages (from pyttsx3) (1.1.7)
# Collecting pypiwin32; platform_system == "Windows"
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, pyttsx3
# Successfully installed pypiwin32-223 pyttsx3-2.90
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda pyaudio
# Out:
# conda-4.10.1         | 2.9 MB    | 9          |   9%
# conda-4.10.1         | 2.9 MB    | 9          |  10%
# conda-4.10.1         | 2.9 MB    | #1         |  11%
# conda-4.10.1         | 2.9 MB    | #1         |  12%
# conda-4.10.1         | 2.9 MB    | #2         |  12%
# conda-4.10.1         | 2.9 MB    | #3         |  13%
# conda-4.10.1         | 2.9 MB    | #4         |  14%
# conda-4.10.1         | 2.9 MB    | #4         |  15%
# conda-4.10.1         | 2.9 MB    | #5         |  15%
# conda-4.10.1         | 2.9 MB    | #5         |  16%
# conda-4.10.1         | 2.9 MB    | #6         |  17%
# conda-4.10.1         | 2.9 MB    | #7         |  18%
# conda-4.10.1         | 2.9 MB    | #9         |  19%
# conda-4.10.1         | 2.9 MB    | #9         |  20%
# conda-4.10.1         | 2.9 MB    | ##         |  20%
# conda-4.10.1         | 2.9 MB    | ##         |  21%
# conda-4.10.1         | 2.9 MB    | ##1        |  22%
# conda-4.10.1         | 2.9 MB    | ##2        |  22%
# conda-4.10.1         | 2.9 MB    | ##3        |  23%
# conda-4.10.1         | 2.9 MB    | ##4        |  24%
# conda-4.10.1         | 2.9 MB    | ##4        |  25%
# conda-4.10.1         | 2.9 MB    | ##5        |  26%
# conda-4.10.1         | 2.9 MB    | ##6        |  26%
# conda-4.10.1         | 2.9 MB    | ##7        |  27%
# conda-4.10.1         | 2.9 MB    | ##7        |  28%
# conda-4.10.1         | 2.9 MB    | ##8        |  29%
# conda-4.10.1         | 2.9 MB    | ##9        |  29%
# conda-4.10.1         | 2.9 MB    | ###        |  31%
# conda-4.10.1         | 2.9 MB    | ###1       |  32%
# conda-4.10.1         | 2.9 MB    | ###2       |  33%
# conda-4.10.1         | 2.9 MB    | ###4       |  34%
# conda-4.10.1         | 2.9 MB    | ###5       |  36%
# conda-4.10.1         | 2.9 MB    | ###6       |  36%
# conda-4.10.1         | 2.9 MB    | ###6       |  37%
# conda-4.10.1         | 2.9 MB    | ###7       |  37%
# conda-4.10.1         | 2.9 MB    | ###8       |  38%
# conda-4.10.1         | 2.9 MB    | ###8       |  39%
# conda-4.10.1         | 2.9 MB    | ###9       |  40%
# conda-4.10.1         | 2.9 MB    | ####       |  40%
# conda-4.10.1         | 2.9 MB    | ####       |  41%
# conda-4.10.1         | 2.9 MB    | ####1      |  41%
# conda-4.10.1         | 2.9 MB    | ####2      |  42%
# conda-4.10.1         | 2.9 MB    | ####4      |  44%
# conda-4.10.1         | 2.9 MB    | ####4      |  45%
# conda-4.10.1         | 2.9 MB    | ####5      |  45%
# conda-4.10.1         | 2.9 MB    | ####5      |  46%
# conda-4.10.1         | 2.9 MB    | ####7      |  47%
# conda-4.10.1         | 2.9 MB    | ####8      |  48%
# conda-4.10.1         | 2.9 MB    | ####9      |  49%
# conda-4.10.1         | 2.9 MB    | ####9      |  50%
# conda-4.10.1         | 2.9 MB    | #####1     |  51%
# conda-4.10.1         | 2.9 MB    | #####1     |  52%
# conda-4.10.1         | 2.9 MB    | #####2     |  52%
# conda-4.10.1         | 2.9 MB    | #####2     |  53%
# conda-4.10.1         | 2.9 MB    | #####3     |  53%
# conda-4.10.1         | 2.9 MB    | #####3     |  54%
# conda-4.10.1         | 2.9 MB    | #####4     |  54%
# conda-4.10.1         | 2.9 MB    | #####4     |  55%
# conda-4.10.1         | 2.9 MB    | #####5     |  55%
# conda-4.10.1         | 2.9 MB    | #####5     |  56%
# conda-4.10.1         | 2.9 MB    | #####6     |  57%
# conda-4.10.1         | 2.9 MB    | #####7     |  58%
# conda-4.10.1         | 2.9 MB    | #####8     |  58%
# conda-4.10.1         | 2.9 MB    | #####8     |  59%
# conda-4.10.1         | 2.9 MB    | #####9     |  60%
# conda-4.10.1         | 2.9 MB    | ######     |  60%
# conda-4.10.1         | 2.9 MB    | ######     |  61%
# conda-4.10.1         | 2.9 MB    | ######1    |  61%
# conda-4.10.1         | 2.9 MB    | ######1    |  62%
# conda-4.10.1         | 2.9 MB    | ######2    |  62%
# conda-4.10.1         | 2.9 MB    | ######3    |  63%
# conda-4.10.1         | 2.9 MB    | ######3    |  64%
# conda-4.10.1         | 2.9 MB    | ######4    |  64%
# conda-4.10.1         | 2.9 MB    | ######4    |  65%
# conda-4.10.1         | 2.9 MB    | ######5    |  65%
# conda-4.10.1         | 2.9 MB    | ######5    |  66%
# conda-4.10.1         | 2.9 MB    | ######6    |  66%
# conda-4.10.1         | 2.9 MB    | ######6    |  67%
# conda-4.10.1         | 2.9 MB    | ######8    |  69%
# conda-4.10.1         | 2.9 MB    | ######9    |  70%
# conda-4.10.1         | 2.9 MB    | #######    |  70%
# conda-4.10.1         | 2.9 MB    | #######    |  71%
# conda-4.10.1         | 2.9 MB    | #######1   |  71%
# conda-4.10.1         | 2.9 MB    | #######1   |  72%
# conda-4.10.1         | 2.9 MB    | #######2   |  72%
# conda-4.10.1         | 2.9 MB    | #######2   |  73%
# conda-4.10.1         | 2.9 MB    | #######3   |  73%
# conda-4.10.1         | 2.9 MB    | #######3   |  74%
# conda-4.10.1         | 2.9 MB    | #######4   |  75%
# conda-4.10.1         | 2.9 MB    | #######5   |  76%
# conda-4.10.1         | 2.9 MB    | #######6   |  76%
# conda-4.10.1         | 2.9 MB    | #######6   |  77%
# conda-4.10.1         | 2.9 MB    | #######7   |  77%
# conda-4.10.1         | 2.9 MB    | #######7   |  78%
# conda-4.10.1         | 2.9 MB    | #######8   |  78%
# conda-4.10.1         | 2.9 MB    | #######8   |  79%
# conda-4.10.1         | 2.9 MB    | #######9   |  79%
# conda-4.10.1         | 2.9 MB    | #######9   |  80%
# conda-4.10.1         | 2.9 MB    | ########   |  80%
# conda-4.10.1         | 2.9 MB    | ########1  |  81%
# conda-4.10.1         | 2.9 MB    | ########2  |  83%
# conda-4.10.1         | 2.9 MB    | ########3  |  84%
# conda-4.10.1         | 2.9 MB    | ########4  |  85%
# conda-4.10.1         | 2.9 MB    | ########5  |  85%
# conda-4.10.1         | 2.9 MB    | ########6  |  87%
# conda-4.10.1         | 2.9 MB    | ########7  |  87%
# conda-4.10.1         | 2.9 MB    | ########8  |  89%
# conda-4.10.1         | 2.9 MB    | ########9  |  90%
# conda-4.10.1         | 2.9 MB    | #########  |  91%
# conda-4.10.1         | 2.9 MB    | #########1 |  92%
# conda-4.10.1         | 2.9 MB    | #########2 |  93%
# conda-4.10.1         | 2.9 MB    | #########3 |  93%
# conda-4.10.1         | 2.9 MB    | #########5 |  95%
# conda-4.10.1         | 2.9 MB    | #########5 |  96%
# conda-4.10.1         | 2.9 MB    | #########6 |  97%
# conda-4.10.1         | 2.9 MB    | #########7 |  98%
# conda-4.10.1         | 2.9 MB    | #########9 |  99%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
#
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    |            |   1%
# openssl-1.1.1h       | 5.8 MB    | 1          |   1%
# openssl-1.1.1h       | 5.8 MB    | 1          |   2%
# openssl-1.1.1h       | 5.8 MB    | 2          |   2%
# openssl-1.1.1h       | 5.8 MB    | 2          |   3%
# openssl-1.1.1h       | 5.8 MB    | 2          |   3%
# openssl-1.1.1h       | 5.8 MB    | 3          |   3%
# openssl-1.1.1h       | 5.8 MB    | 3          |   4%
# openssl-1.1.1h       | 5.8 MB    | 3          |   4%
# openssl-1.1.1h       | 5.8 MB    | 4          |   4%
# openssl-1.1.1h       | 5.8 MB    | 4          |   4%
# openssl-1.1.1h       | 5.8 MB    | 4          |   5%
# openssl-1.1.1h       | 5.8 MB    | 4          |   5%
# openssl-1.1.1h       | 5.8 MB    | 5          |   5%
# openssl-1.1.1h       | 5.8 MB    | 5          |   5%
# openssl-1.1.1h       | 5.8 MB    | 5          |   6%
# openssl-1.1.1h       | 5.8 MB    | 5          |   6%
# openssl-1.1.1h       | 5.8 MB    | 6          |   6%
# openssl-1.1.1h       | 5.8 MB    | 6          |   7%
# openssl-1.1.1h       | 5.8 MB    | 6          |   7%
# openssl-1.1.1h       | 5.8 MB    | 7          |   7%
# openssl-1.1.1h       | 5.8 MB    | 7          |   8%
# openssl-1.1.1h       | 5.8 MB    | 7          |   8%
# openssl-1.1.1h       | 5.8 MB    | 8          |   8%
# openssl-1.1.1h       | 5.8 MB    | 8          |   8%
# openssl-1.1.1h       | 5.8 MB    | 8          |   9%
# openssl-1.1.1h       | 5.8 MB    | 8          |   9%
# openssl-1.1.1h       | 5.8 MB    | 9          |   9%
# openssl-1.1.1h       | 5.8 MB    | 9          |  10%
# openssl-1.1.1h       | 5.8 MB    | 9          |  10%
# openssl-1.1.1h       | 5.8 MB    | #          |  10%
# openssl-1.1.1h       | 5.8 MB    | #          |  10%
# openssl-1.1.1h       | 5.8 MB    | #          |  11%
# openssl-1.1.1h       | 5.8 MB    | #          |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  12%
# openssl-1.1.1h       | 5.8 MB    | #1         |  12%
# openssl-1.1.1h       | 5.8 MB    | #2         |  12%
# openssl-1.1.1h       | 5.8 MB    | #2         |  12%
# openssl-1.1.1h       | 5.8 MB    | #2         |  13%
# openssl-1.1.1h       | 5.8 MB    | #3         |  13%
# openssl-1.1.1h       | 5.8 MB    | #3         |  13%
# openssl-1.1.1h       | 5.8 MB    | #3         |  14%
# openssl-1.1.1h       | 5.8 MB    | #3         |  14%
# openssl-1.1.1h       | 5.8 MB    | #4         |  14%
# openssl-1.1.1h       | 5.8 MB    | #4         |  14%
# openssl-1.1.1h       | 5.8 MB    | #4         |  15%
# openssl-1.1.1h       | 5.8 MB    | #4         |  15%
# openssl-1.1.1h       | 5.8 MB    | #5         |  15%
# openssl-1.1.1h       | 5.8 MB    | #5         |  15%
# openssl-1.1.1h       | 5.8 MB    | #5         |  16%
# openssl-1.1.1h       | 5.8 MB    | #6         |  16%
# openssl-1.1.1h       | 5.8 MB    | #6         |  16%
# openssl-1.1.1h       | 5.8 MB    | #6         |  17%
# openssl-1.1.1h       | 5.8 MB    | #6         |  17%
# openssl-1.1.1h       | 5.8 MB    | #7         |  17%
# openssl-1.1.1h       | 5.8 MB    | #7         |  17%
# openssl-1.1.1h       | 5.8 MB    | #7         |  18%
# openssl-1.1.1h       | 5.8 MB    | #8         |  18%
# openssl-1.1.1h       | 5.8 MB    | #8         |  18%
# openssl-1.1.1h       | 5.8 MB    | #8         |  19%
# openssl-1.1.1h       | 5.8 MB    | #9         |  19%
# openssl-1.1.1h       | 5.8 MB    | #9         |  19%
# openssl-1.1.1h       | 5.8 MB    | #9         |  20%
# openssl-1.1.1h       | 5.8 MB    | #9         |  20%
# openssl-1.1.1h       | 5.8 MB    | ##         |  20%
# openssl-1.1.1h       | 5.8 MB    | ##         |  20%
# openssl-1.1.1h       | 5.8 MB    | ##         |  21%
# openssl-1.1.1h       | 5.8 MB    | ##         |  21%
# openssl-1.1.1h       | 5.8 MB    | ##1        |  21%
# openssl-1.1.1h       | 5.8 MB    | ##1        |  22%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  22%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  22%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  25%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  25%
# openssl-1.1.1h       | 5.8 MB    | ##5        |  26%
# openssl-1.1.1h       | 5.8 MB    | ##6        |  26%
# openssl-1.1.1h       | 5.8 MB    | ##6        |  27%
# openssl-1.1.1h       | 5.8 MB    | ##7        |  27%
# openssl-1.1.1h       | 5.8 MB    | ##7        |  28%
# openssl-1.1.1h       | 5.8 MB    | ##8        |  29%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  30%
# openssl-1.1.1h       | 5.8 MB    | ###        |  31%
# openssl-1.1.1h       | 5.8 MB    | ###1       |  32%
# openssl-1.1.1h       | 5.8 MB    | ###2       |  33%
# openssl-1.1.1h       | 5.8 MB    | ###4       |  34%
# openssl-1.1.1h       | 5.8 MB    | ###5       |  35%
# openssl-1.1.1h       | 5.8 MB    | ###6       |  36%
# openssl-1.1.1h       | 5.8 MB    | ###6       |  37%
# openssl-1.1.1h       | 5.8 MB    | ###7       |  38%
# openssl-1.1.1h       | 5.8 MB    | ###8       |  39%
# openssl-1.1.1h       | 5.8 MB    | ###9       |  40%
# openssl-1.1.1h       | 5.8 MB    | ####2      |  42%
# openssl-1.1.1h       | 5.8 MB    | ####2      |  43%
# openssl-1.1.1h       | 5.8 MB    | ####3      |  43%
# openssl-1.1.1h       | 5.8 MB    | ####3      |  44%
# openssl-1.1.1h       | 5.8 MB    | ####4      |  44%
# openssl-1.1.1h       | 5.8 MB    | ####4      |  45%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  45%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  46%
# openssl-1.1.1h       | 5.8 MB    | ####7      |  47%
# openssl-1.1.1h       | 5.8 MB    | ####7      |  48%
# openssl-1.1.1h       | 5.8 MB    | ####8      |  48%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  49%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  50%
# openssl-1.1.1h       | 5.8 MB    | #####1     |  51%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  52%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  53%
# openssl-1.1.1h       | 5.8 MB    | #####3     |  54%
# openssl-1.1.1h       | 5.8 MB    | #####4     |  55%
# openssl-1.1.1h       | 5.8 MB    | #####5     |  55%
# openssl-1.1.1h       | 5.8 MB    | #####5     |  56%
# openssl-1.1.1h       | 5.8 MB    | #####6     |  57%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  57%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####8     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####8     |  59%
# openssl-1.1.1h       | 5.8 MB    | #####9     |  60%
# openssl-1.1.1h       | 5.8 MB    | ######     |  61%
# openssl-1.1.1h       | 5.8 MB    | ######1    |  61%
# openssl-1.1.1h       | 5.8 MB    | ######1    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######2    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  63%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  63%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  65%
# openssl-1.1.1h       | 5.8 MB    | ######5    |  66%
# openssl-1.1.1h       | 5.8 MB    | ######6    |  66%
# openssl-1.1.1h       | 5.8 MB    | ######7    |  67%
# openssl-1.1.1h       | 5.8 MB    | ######7    |  68%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  69%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  69%
# openssl-1.1.1h       | 5.8 MB    | #######    |  70%
# openssl-1.1.1h       | 5.8 MB    | #######1   |  72%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  72%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  73%
# openssl-1.1.1h       | 5.8 MB    | #######3   |  73%
# openssl-1.1.1h       | 5.8 MB    | #######3   |  74%
# openssl-1.1.1h       | 5.8 MB    | #######4   |  74%
# openssl-1.1.1h       | 5.8 MB    | #######4   |  75%
# openssl-1.1.1h       | 5.8 MB    | #######6   |  76%
# openssl-1.1.1h       | 5.8 MB    | #######6   |  77%
# openssl-1.1.1h       | 5.8 MB    | #######7   |  77%
# openssl-1.1.1h       | 5.8 MB    | #######7   |  78%
# openssl-1.1.1h       | 5.8 MB    | #######8   |  79%
# openssl-1.1.1h       | 5.8 MB    | #######9   |  79%
# openssl-1.1.1h       | 5.8 MB    | ########   |  80%
# openssl-1.1.1h       | 5.8 MB    | ########   |  81%
# openssl-1.1.1h       | 5.8 MB    | ########1  |  82%
# openssl-1.1.1h       | 5.8 MB    | ########2  |  83%
# openssl-1.1.1h       | 5.8 MB    | ########3  |  83%
# openssl-1.1.1h       | 5.8 MB    | ########3  |  84%
# openssl-1.1.1h       | 5.8 MB    | ########4  |  85%
# openssl-1.1.1h       | 5.8 MB    | ########5  |  86%
# openssl-1.1.1h       | 5.8 MB    | ########6  |  86%
# openssl-1.1.1h       | 5.8 MB    | ########6  |  87%
# openssl-1.1.1h       | 5.8 MB    | ########7  |  87%
# openssl-1.1.1h       | 5.8 MB    | ########7  |  88%
# openssl-1.1.1h       | 5.8 MB    | ########8  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########9  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########9  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########  |  91%
# openssl-1.1.1h       | 5.8 MB    | #########1 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########2 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########3 |  93%
# openssl-1.1.1h       | 5.8 MB    | #########3 |  94%
# openssl-1.1.1h       | 5.8 MB    | #########5 |  95%
# openssl-1.1.1h       | 5.8 MB    | #########5 |  96%
# openssl-1.1.1h       | 5.8 MB    | #########6 |  97%
# openssl-1.1.1h       | 5.8 MB    | #########7 |  98%
# openssl-1.1.1h       | 5.8 MB    | #########8 |  99%
# openssl-1.1.1h       | 5.8 MB    | #########9 | 100%
# openssl-1.1.1h       | 5.8 MB    | ########## | 100%
#
# ca-certificates-2020 | 159 KB    |            |   0%
# ca-certificates-2020 | 159 KB    | #          |  10%
# ca-certificates-2020 | 159 KB    | ####       |  40%
# ca-certificates-2020 | 159 KB    | ########   |  80%
# ca-certificates-2020 | 159 KB    | ########## | 100%
# ca-certificates-2020 | 159 KB    | ########## | 100%
#
# pyaudio-0.2.11       | 189 KB    |            |   0%
# pyaudio-0.2.11       | 189 KB    | 8          |   8%
# pyaudio-0.2.11       | 189 KB    | ####2      |  42%
# pyaudio-0.2.11       | 189 KB    | #######6   |  76%
# pyaudio-0.2.11       | 189 KB    | ########## | 100%
# pyaudio-0.2.11       | 189 KB    | ########## | 100%
#
# portaudio-19.6.0     | 240 KB    |            |   0%
# portaudio-19.6.0     | 240 KB    | 6          |   7%
# portaudio-19.6.0     | 240 KB    | ###3       |  33%
# portaudio-19.6.0     | 240 KB    | ######     |  60%
# portaudio-19.6.0     | 240 KB    | ########6  |  87%
# portaudio-19.6.0     | 240 KB    | ########## | 100%
# portaudio-19.6.0     | 240 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Failed to create temp directory "C:\Users\Om\AppData\Local\Temp\conda-<RANDOM>\"
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Failed to create temp directory "C:\Users\Om\AppData\Local\Temp\conda-<RANDOM>\"
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pywhatkit
# Out:
# Collecting pywhatkit
#   Downloading pywhatkit-4.1-py3-none-any.whl (9.1 kB)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.52.tar.gz (55 kB)
# Requirement already satisfied: Pillow in g:\anaconda2\lib\site-packages (from pywhatkit) (8.0.1)
# Requirement already satisfied: requests in g:\anaconda2\lib\site-packages (from pywhatkit) (2.24.0)
# Requirement already satisfied: beautifulsoup4 in g:\anaconda2\lib\site-packages (from wikipedia->pywhatkit) (4.9.3)
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: startedNote: you may need to restart the kernel to use updated packages.
#     Preparing wheel metadata: finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in g:\anaconda2\lib\site-packages (from requests->pywhatkit) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in g:\anaconda2\lib\site-packages (from requests->pywhatkit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in g:\anaconda2\lib\site-packages (from requests->pywhatkit) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in g:\anaconda2\lib\site-packages (from requests->pywhatkit) (2.10)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in g:\anaconda2\lib\site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.0.1)
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: wikipedia, pyautogui, pymsgbox, PyTweening, pyscreeze, pygetwindow, mouseinfo, pyrect, pyperclip
#   Building wheel for wikipedia (setup.py): started
#   Building wheel for wikipedia (setup.py): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11689 sha256=31b1e44668500c52b536787d9dc0a9a435b5ed3984bd804498f311e5af475798
#
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\07\93\05\72c05349177dca2e0ba31a33ba4f7907606f7ddef303517c6a
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-py3-none-any.whl size=35198 sha256=7490c2c69889e567b050f97b68cca6befbe945c33e72ce93250aff531ee86362
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\4d\0d\6a\4258cb741835ea9ce7897652ae88272d3baf5cb1944c1984aa
#   Building wheel for pymsgbox (PEP 517): started
#   Building wheel for pymsgbox (PEP 517): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=d4e8c3c20d925d2b507f9dfe26a79ff834977e0bd1110c75e5d2e7babdf73f27
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3820 sha256=0e701bee631af9cb3034dd02fb0197e054775cdf2e1847c3a378e7c88ce3e32e
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\e7\50\20\790fbd95739abfdf0348bef99d5cc0c7c2930a19a91f602ddc
#   Building wheel for pyscreeze (PEP 517): started
#   Building wheel for pyscreeze (PEP 517): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-py3-none-any.whl size=12864 sha256=806bb0bcade6ed9faeba384d5cdfc620beecafa9e7d81b830d892dc8822cf6ac
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\f7\91\eb\c0fa176c095c77460a579ef339f24a377474b041e5543d1a00
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11084 sha256=303b8f3dcaa3ae57f6bd7a5bea48b968da611f66382eae23f4fafa89d916a825
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10910 sha256=bebcf0e7c23f40f3913ecf5a59bfb05881f47f055531f28d74a8ea21482e1c98
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9552 sha256=eda8076d611ddcd6c7dfb6e080c5f0e8cf9654f8f44157f6d26116fefbce5007
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\d1\e4\47\c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11112 sha256=d69b2246749212a53a40c35b4058c48f96ea49d26d4f4a456db12210a7a1e8a8
#   Stored in directory: c:\users\om!\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built wikipedia pyautogui pymsgbox PyTweening pyscreeze pygetwindow mouseinfo pyrect pyperclip
# Installing collected packages: wikipedia, pymsgbox, PyTweening, pyscreeze, pyrect, pygetwindow, pyperclip, mouseinfo, pyautogui, pywhatkit
# Successfully installed PyTweening-1.0.3 mouseinfo-0.1.3 pyautogui-0.9.52 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.27 pywhatkit-4.1 wikipedia-1.4.0

# %%
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in g:\anaconda2\lib\site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in g:\anaconda2\lib\site-packages (from wikipedia) (2.24.0)
# Requirement already satisfied: beautifulsoup4 in g:\anaconda2\lib\site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: certifi>=2017.4.17 in g:\anaconda2\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in g:\anaconda2\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in g:\anaconda2\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in g:\anaconda2\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in g:\anaconda2\lib\site-packages (from beautifulsoup4->wikipedia) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import pywhatkit
import wikipedia
listener = sr.Recognizer()
alexa = pyttsx3.init()

voices = alexa.getProperty('voices')
alexa.setProperty('voice', voices[1].id)

def talk(text):
    alexa.say(text)
    alexa.runAndWait()

def take_command():
    
    try:
        with sr.Microphone() as source:
            print('Device is listening, please speak...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'alexa' in command:
                command = command.replace('alexa', '')
    except:   
        pass
    return command

def run_alexa():
    command = take_command()
    
    if 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        print('Current time is ' + time)
        talk('Current time is ' + time) 
    elif 'play' in command:
        song = command.replace('play', '')
        talk('playing ' + song)
        pywhatkit.playonyt(song)
    elif 'tell me about' in command:
        wiki = command.replace('tell me about', '')
        info = wikipedia.summary(wiki, 2)
        print(info)
        talk(info)
    else:
        talk('Sorry I didnot get your question, I can search it from google')
        pywhatkit.search(command)
             
        
run_alexa()
# Out:
# Device is listening, please speak...
